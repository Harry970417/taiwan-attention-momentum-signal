# %% [markdown]
# # 04 - Institutional Flow Control Demo
# Demonstrates whether foreign/investment-trust/dealer trading flow explains the attention-momentum effect. See `src/institutional_flow.py`, `src/regression_analysis.py`, `src/triple_sort.py`.
#
# **Unit note**: FinMind's free institutional data is in shares, not NTD value -- see `docs/limitations.md`.

# %%
import pandas as pd

reg = pd.read_csv('../results/tables/v04_regression_with_chips_summary.csv')
reg[['model', 'horizon', 'coefficient', 't_stat', 'p_value', 'significant']]

# %% [markdown]
# attention_z's coefficient barely moves when institutional flow controls are added (compare Model A vs B) -- contrast this with the ~36% shrinkage from momentum controls in notebook 03.

# %%
interaction = pd.read_csv('../results/tables/v04_interaction_model_summary.csv')
interaction

# %%
from IPython.display import Image
display(Image('../results/figures/v04_attention_chip_correlation_heatmap.png'))
display(Image('../results/figures/v04_triple_sort_winner_group_heatmap.png'))
