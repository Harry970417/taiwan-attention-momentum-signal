# %% [markdown]
# # 01 - Data Collection Demo
# Demonstrates the Google Trends (anchor-batched) and FinMind REST API collectors on the 50-stock universe. See `src/trends_collector.py` and `src/stock_data_loader.py`.
#
# **Note**: running this for real re-collects from live public APIs and can take 30+ minutes due to Google Trends rate limiting. This notebook just shows how to invoke it.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path('..').resolve() / 'src'))
import pandas as pd

stocks = pd.read_csv('../config/stock_list_50.csv')
stocks.head(10)

# %%
# Uncomment to actually run the collectors (writes to ../data/raw/)
# import trends_collector, stock_data_loader
# trends_collector.main()
# stock_data_loader.main()

# %%
# Inspect the shipped small sample instead (3 stocks x 20 weeks)
sample = pd.read_csv('../data/sample/attention_weekly_panel_sample.csv')
sample.head()
