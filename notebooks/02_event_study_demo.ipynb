# %% [markdown]
# # 02 - Event Study (CAAR) Demo
# Demonstrates the attention factor construction and CAAR event study. See `src/attention_factor.py` and `src/event_study.py`.
#
# Requires the full panel (`data/processed/attention_weekly_panel_v03.csv`), which is not shipped in this repo -- run `scripts/run_data_collection.py` then `scripts/run_event_study.py` first, or inspect the pre-computed result tables in `results/tables/` (e.g. `caar_event_summary.csv`).

# %%
import pandas as pd

caar_summary = pd.read_csv('../results/tables/caar_event_summary.csv')
caar_summary

# %%
from IPython.display import Image
Image('../results/figures/caar_attention_z2.png')

# %%
# To regenerate from scratch:
# import sys, pathlib
# sys.path.insert(0, str(pathlib.Path('..').resolve() / 'src'))
# import attention_factor, event_study, visualization
# attention_factor.main()
# event_study.main()
# visualization.main()
